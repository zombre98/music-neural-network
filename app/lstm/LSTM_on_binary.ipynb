# %%
import os
import json

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from app.features.DataMIDI import File

# %%
import pandas

dtype = {
    'canonical_composer': 'category',
    'canonical_title': 'object',
    'split': 'category',
    'year': 'int64',
    'midi_filename': 'object',
    'audio_filename': 'object',
    'duration': 'float64'
}
dataset = pandas.read_json('../../data/maestro-v2.0.0/maestro-v2.0.0.json')
dataset = dataset.astype(dtype)

# %%
def filesize(filename):
    return os.path.getsize('../../data/maestro-v2.0.0/' + filename)

def read_file(filename):
    with open('../../data/maestro-v2.0.0/' + filename, 'rb') as f:
        return f.read()
    
def bytes_as_array(limit):
    def with_limit(file):
        return np.frombuffer(file[0:limit], dtype='int8') / 255.0
    return with_limit

def code_to_label(code):
    return dataset.canonical_composer.cat.categories[code][0]

testing = pandas.DataFrame(dataset).sample(frac=1).reset_index(drop=True)
testing['midi_filesize'] = testing['midi_filename'].apply(filesize)
testing['midi_file'] = testing['midi_filename'].apply(read_file)
testing['bytes_features'] = testing['midi_file'].apply(bytes_as_array(testing.midi_filesize.min()))
testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1282 entries, 0 to 1281
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   canonical_composer  1282 non-null   category
#  1   canonical_title     1282 non-null   object
#  2   split               1282 non-null   category
#  3   year                1282 non-null   int64
#  4   midi_filename       1282 non-null   object
#  5   audio_filename      1282 non-null   object
#  6   duration            1282 non-null   float64
#  7   midi_filesize       1282 non-null   int64
#  8   midi_file           1282 non-null   object
#  9   bytes_features      1282 non-null   object
# dtypes: category(2), float64(1), int64(2), object(5)
# memory usage: 85.8+ KB

# %%
input_dim = 1
# input_dim = 28

units = 128
output_size = len(testing.canonical_composer.cat.categories)
print(f'output_size: {output_size}')
# output_size = 10

# Build the RNN model
def build_model():
    lstm_layer = keras.layers.LSTM(units, input_shape=(None, input_dim))
    return keras.models.Sequential(
        [
            lstm_layer,
            keras.layers.BatchNormalization(),
            keras.layers.Dense(output_size),
        ]
    )
# Out:
# output_size: 61

# %%
train = testing[testing.split == 'train']
test = testing[testing.split == 'test']
x_train = np.vstack(train['bytes_features']).reshape(len(train.index), -1, 1)
y_train = np.asarray(train['canonical_composer'].cat.codes)
x_test = np.vstack(test['bytes_features']).reshape(len(test.index), -1, 1)
y_test = np.asarray(test['canonical_composer'].cat.codes)

print('dataset created:')
print(f'train: {x_train.shape}, {y_train.shape}')
print(f'test:  {x_test.shape}, {y_test.shape}')

model = build_model()
model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer="adam",
    metrics=["accuracy"],
)

model.summary()


checkpoint = keras.callbacks.ModelCheckpoint(
    os.path.join(os.getcwd(), 'saved_models', 'best.hdf5'),
    monitor='val_accuracy', verbose=1,
    save_best_only=True, mode='max'
)


model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=16, epochs=20, callbacks=[checkpoint])
# Out:
# dataset created:
# train: (967, 3096, 1), (967,)
# test:  (178, 3096, 1), (178,)
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_34 (LSTM)               (None, 128)               66560
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 128)               512
# _________________________________________________________________
# dense_34 (Dense)             (None, 61)                7869
# =================================================================
# Total params: 74,941
# Trainable params: 74,685
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/20
# 61/61 [==============================] - ETA: 0s - loss: 3.9768 - accuracy: 0.1065
# Epoch 00001: val_accuracy improved from -inf to 0.15169, saving model to C:\Users\Armand\Code\music-neural-network\app\lstm\saved_models\best.hdf5
# 61/61 [==============================] - 9s 153ms/step - loss: 3.9768 - accuracy: 0.1065 - val_loss: 3.7856 - val_accuracy: 0.1517
# Epoch 2/20
# 61/61 [==============================] - ETA: 0s - loss: 3.4880 - accuracy: 0.1644
# Epoch 00002: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 3.4880 - accuracy: 0.1644 - val_loss: 3.0998 - val_accuracy: 0.1292
# Epoch 3/20
# 61/61 [==============================] - ETA: 0s - loss: 2.9568 - accuracy: 0.1582
# Epoch 00003: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 2.9568 - accuracy: 0.1582 - val_loss: 2.8064 - val_accuracy: 0.1292
# Epoch 4/20
# 61/61 [==============================] - ETA: 0s - loss: 2.8155 - accuracy: 0.1644
# Epoch 00004: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 2.8155 - accuracy: 0.1644 - val_loss: 2.7578 - val_accuracy: 0.1292
# Epoch 5/20
# 61/61 [==============================] - ETA: 0s - loss: 2.8019 - accuracy: 0.1696
# Epoch 00005: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 145ms/step - loss: 2.8019 - accuracy: 0.1696 - val_loss: 2.7435 - val_accuracy: 0.1292
# Epoch 6/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7949 - accuracy: 0.1624
# Epoch 00006: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 145ms/step - loss: 2.7949 - accuracy: 0.1624 - val_loss: 2.7443 - val_accuracy: 0.1348
# Epoch 7/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7894 - accuracy: 0.1665
# Epoch 00007: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 2.7894 - accuracy: 0.1665 - val_loss: 2.8374 - val_accuracy: 0.1404
# Epoch 8/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7795 - accuracy: 0.1634
# Epoch 00008: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 2.7795 - accuracy: 0.1634 - val_loss: 2.9204 - val_accuracy: 0.0955
# Epoch 9/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7831 - accuracy: 0.1603
# Epoch 00009: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 143ms/step - loss: 2.7831 - accuracy: 0.1603 - val_loss: 2.7736 - val_accuracy: 0.1404
# Epoch 10/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7696 - accuracy: 0.1572
# Epoch 00010: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 2.7696 - accuracy: 0.1572 - val_loss: 2.7337 - val_accuracy: 0.1292
# Epoch 11/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7615 - accuracy: 0.1541
# Epoch 00011: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 2.7615 - accuracy: 0.1541 - val_loss: 2.8126 - val_accuracy: 0.1348
# Epoch 12/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7549 - accuracy: 0.1551
# Epoch 00012: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 2.7549 - accuracy: 0.1551 - val_loss: 3.0824 - val_accuracy: 0.0955
# Epoch 13/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7527 - accuracy: 0.1624
# Epoch 00013: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 145ms/step - loss: 2.7527 - accuracy: 0.1624 - val_loss: 4.6334 - val_accuracy: 0.0056
# Epoch 14/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7476 - accuracy: 0.1665
# Epoch 00014: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 2.7476 - accuracy: 0.1665 - val_loss: 4.1155 - val_accuracy: 0.0674
# Epoch 15/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7526 - accuracy: 0.1717
# Epoch 00015: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 2.7526 - accuracy: 0.1717 - val_loss: 3.0204 - val_accuracy: 0.0843
# Epoch 16/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7378 - accuracy: 0.1603
# Epoch 00016: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 2.7378 - accuracy: 0.1603 - val_loss: 3.2800 - val_accuracy: 0.1067
# Epoch 17/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7528 - accuracy: 0.1572
# Epoch 00017: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 2.7528 - accuracy: 0.1572 - val_loss: 4.1204 - val_accuracy: 0.0000e+00
# Epoch 18/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7451 - accuracy: 0.1634
# Epoch 00018: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 2.7451 - accuracy: 0.1634 - val_loss: 3.7334 - val_accuracy: 0.1236
# Epoch 19/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7266 - accuracy: 0.1593
# Epoch 00019: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 145ms/step - loss: 2.7266 - accuracy: 0.1593 - val_loss: 3.2848 - val_accuracy: 0.0955
# Epoch 20/20
# 61/61 [==============================] - ETA: 0s - loss: 2.7366 - accuracy: 0.1737
# Epoch 00020: val_accuracy did not improve from 0.15169
# 61/61 [==============================] - 9s 144ms/step - loss: 2.7366 - accuracy: 0.1737 - val_loss: 12.9909 - val_accuracy: 0.0169

# %%
idx = np.random.choice(len(x_train))
sample, sample_label = x_train[idx], y_train[idx]

test_model = build_model()
test_model.load_weights(os.path.join(os.getcwd(), 'saved_models', 'best.hdf5'))
result = tf.argmax(test_model.predict_on_batch(tf.expand_dims(sample, 0)), axis=1)
print(f'Predicted result is: {code_to_label(result.numpy())}, target result is: {code_to_label([sample_label])}')
# Out:
# Predicted result is: Johann Sebastian Bach, target result is: Franz Liszt

# %%
from sklearn.model_selection import KFold

save_dir = './k_fold_models/'

def get_model_name(k):
    return 'model_' + str(k) + '.h5'

x_data = np.vstack(testing['bytes_features']).reshape(len(testing.index), -1, 1)
y_data = np.asarray(testing['canonical_composer'].cat.codes)

kf = KFold(5)
fold_no = 1

k_fold_model = build_model()
k_fold_model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer="adam",
    metrics=["accuracy"]
)
    
for train_index, test_index in kf.split(x_data):
    x_train, x_test = x_data[train_index], x_data[test_index]
    y_train, y_test = y_data[train_index], y_data[test_index]
    
    checkpoint = keras.callbacks.ModelCheckpoint(save_dir + get_model_name(fold_no),
        monitor='val_accuracy', verbose=1,
        save_best_only=True, mode='max')

    k_fold_model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=4, epochs=10, callbacks=[checkpoint])
    
    fold_no += 1
# Out:
# Epoch 1/10
# 257/257 [==============================] - ETA: 0s - loss: 3.3936 - accuracy: 0.1327
# Epoch 00001: val_accuracy improved from -inf to 0.17510, saving model to ./k_fold_models/model_1.h5
# 257/257 [==============================] - 31s 119ms/step - loss: 3.3936 - accuracy: 0.1327 - val_loss: 2.8754 - val_accuracy: 0.1751
# Epoch 2/10
# 257/257 [==============================] - ETA: 0s - loss: 2.8171 - accuracy: 0.1512
# Epoch 00002: val_accuracy did not improve from 0.17510
# 257/257 [==============================] - 30s 116ms/step - loss: 2.8171 - accuracy: 0.1512 - val_loss: 2.8794 - val_accuracy: 0.0973
# Epoch 3/10
# 257/257 [==============================] - ETA: 0s - loss: 2.8007 - accuracy: 0.1551
# Epoch 00003: val_accuracy did not improve from 0.17510
# 257/257 [==============================] - 30s 116ms/step - loss: 2.8007 - accuracy: 0.1551 - val_loss: 2.9026 - val_accuracy: 0.1556
# Epoch 4/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7944 - accuracy: 0.1522
# Epoch 00004: val_accuracy did not improve from 0.17510
# 257/257 [==============================] - 31s 120ms/step - loss: 2.7944 - accuracy: 0.1522 - val_loss: 2.9425 - val_accuracy: 0.0661
# Epoch 5/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7852 - accuracy: 0.1620
# Epoch 00005: val_accuracy did not improve from 0.17510
# 257/257 [==============================] - 30s 117ms/step - loss: 2.7852 - accuracy: 0.1620 - val_loss: 2.9490 - val_accuracy: 0.1634
# Epoch 6/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7837 - accuracy: 0.1571
# Epoch 00006: val_accuracy did not improve from 0.17510
# 257/257 [==============================] - 30s 117ms/step - loss: 2.7837 - accuracy: 0.1571 - val_loss: 2.8999 - val_accuracy: 0.1440
# Epoch 7/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7828 - accuracy: 0.1522
# Epoch 00007: val_accuracy did not improve from 0.17510
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7828 - accuracy: 0.1522 - val_loss: 54.7070 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 257/257 [==============================] - ETA: 0s - loss: 2.8059 - accuracy: 0.1473
# Epoch 00008: val_accuracy did not improve from 0.17510
# 257/257 [==============================] - 30s 118ms/step - loss: 2.8059 - accuracy: 0.1473 - val_loss: 3.9106 - val_accuracy: 0.0506
# Epoch 9/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7952 - accuracy: 0.1483
# Epoch 00009: val_accuracy did not improve from 0.17510
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7952 - accuracy: 0.1483 - val_loss: 8.1152 - val_accuracy: 0.0817
# Epoch 10/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7838 - accuracy: 0.1512
# Epoch 00010: val_accuracy did not improve from 0.17510
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7838 - accuracy: 0.1512 - val_loss: 17.0253 - val_accuracy: 0.0000e+00
# Epoch 1/10
# 257/257 [==============================] - ETA: 0s - loss: 2.8100 - accuracy: 0.1493
# Epoch 00001: val_accuracy improved from -inf to 0.05058, saving model to ./k_fold_models/model_2.h5
# 257/257 [==============================] - 31s 119ms/step - loss: 2.8100 - accuracy: 0.1493 - val_loss: 5.8202 - val_accuracy: 0.0506
# Epoch 2/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7970 - accuracy: 0.1707
# Epoch 00002: val_accuracy improved from 0.05058 to 0.12451, saving model to ./k_fold_models/model_2.h5
# 257/257 [==============================] - 31s 119ms/step - loss: 2.7970 - accuracy: 0.1707 - val_loss: 4.0369 - val_accuracy: 0.1245
# Epoch 3/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7900 - accuracy: 0.1590
# Epoch 00003: val_accuracy did not improve from 0.12451
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7900 - accuracy: 0.1590 - val_loss: 20.5466 - val_accuracy: 0.0039
# Epoch 4/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7829 - accuracy: 0.1649
# Epoch 00004: val_accuracy did not improve from 0.12451
# 257/257 [==============================] - 30s 119ms/step - loss: 2.7829 - accuracy: 0.1649 - val_loss: 23.1163 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7851 - accuracy: 0.1610
# Epoch 00005: val_accuracy did not improve from 0.12451
# 257/257 [==============================] - 30s 117ms/step - loss: 2.7851 - accuracy: 0.1610 - val_loss: 11.3071 - val_accuracy: 0.0039
# Epoch 6/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7748 - accuracy: 0.1766
# Epoch 00006: val_accuracy did not improve from 0.12451
# 257/257 [==============================] - 30s 116ms/step - loss: 2.7748 - accuracy: 0.1766 - val_loss: 14.4647 - val_accuracy: 0.0039
# Epoch 7/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7700 - accuracy: 0.1473
# Epoch 00007: val_accuracy improved from 0.12451 to 0.13230, saving model to ./k_fold_models/model_2.h5
# 257/257 [==============================] - 30s 117ms/step - loss: 2.7700 - accuracy: 0.1473 - val_loss: 7.3104 - val_accuracy: 0.1323
# Epoch 8/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7612 - accuracy: 0.1678
# Epoch 00008: val_accuracy did not improve from 0.13230
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7612 - accuracy: 0.1678 - val_loss: 8.3144 - val_accuracy: 0.1167
# Epoch 9/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7552 - accuracy: 0.1620
# Epoch 00009: val_accuracy did not improve from 0.13230
# 257/257 [==============================] - 31s 119ms/step - loss: 2.7552 - accuracy: 0.1620 - val_loss: 10.4157 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7486 - accuracy: 0.1639
# Epoch 00010: val_accuracy did not improve from 0.13230
# 257/257 [==============================] - 31s 119ms/step - loss: 2.7486 - accuracy: 0.1639 - val_loss: 3.6529 - val_accuracy: 0.1051
# Epoch 1/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7820 - accuracy: 0.1676
# Epoch 00001: val_accuracy improved from -inf to 0.00391, saving model to ./k_fold_models/model_3.h5
# 257/257 [==============================] - 31s 120ms/step - loss: 2.7820 - accuracy: 0.1676 - val_loss: 6.9881 - val_accuracy: 0.0039
# Epoch 2/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7708 - accuracy: 0.1696
# Epoch 00002: val_accuracy did not improve from 0.00391
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7708 - accuracy: 0.1696 - val_loss: 16.3934 - val_accuracy: 0.0039
# Epoch 3/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7743 - accuracy: 0.1657
# Epoch 00003: val_accuracy improved from 0.00391 to 0.14453, saving model to ./k_fold_models/model_3.h5
# 257/257 [==============================] - 30s 119ms/step - loss: 2.7743 - accuracy: 0.1657 - val_loss: 3.0175 - val_accuracy: 0.1445
# Epoch 4/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7563 - accuracy: 0.1657
# Epoch 00004: val_accuracy did not improve from 0.14453
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7563 - accuracy: 0.1657 - val_loss: 36.4026 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7494 - accuracy: 0.1745
# Epoch 00005: val_accuracy did not improve from 0.14453
# 257/257 [==============================] - 30s 117ms/step - loss: 2.7494 - accuracy: 0.1745 - val_loss: 4.9631 - val_accuracy: 0.0234
# Epoch 6/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7532 - accuracy: 0.1628
# Epoch 00006: val_accuracy did not improve from 0.14453
# 257/257 [==============================] - 30s 117ms/step - loss: 2.7532 - accuracy: 0.1628 - val_loss: 8.1418 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7360 - accuracy: 0.1706
# Epoch 00007: val_accuracy improved from 0.14453 to 0.15234, saving model to ./k_fold_models/model_3.h5
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7360 - accuracy: 0.1706 - val_loss: 3.6943 - val_accuracy: 0.1523
# Epoch 8/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7279 - accuracy: 0.1647
# Epoch 00008: val_accuracy did not improve from 0.15234
# 257/257 [==============================] - 30s 117ms/step - loss: 2.7279 - accuracy: 0.1647 - val_loss: 11.5975 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7314 - accuracy: 0.1745
# Epoch 00009: val_accuracy did not improve from 0.15234
# 257/257 [==============================] - 30s 119ms/step - loss: 2.7314 - accuracy: 0.1745 - val_loss: 19.4535 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7198 - accuracy: 0.1628
# Epoch 00010: val_accuracy did not improve from 0.15234
# 257/257 [==============================] - 30s 117ms/step - loss: 2.7198 - accuracy: 0.1628 - val_loss: 14.8218 - val_accuracy: 0.0000e+00
# Epoch 1/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7470 - accuracy: 0.1491
# Epoch 00001: val_accuracy improved from -inf to 0.00781, saving model to ./k_fold_models/model_4.h5
# 257/257 [==============================] - 30s 117ms/step - loss: 2.7470 - accuracy: 0.1491 - val_loss: 6.5269 - val_accuracy: 0.0078
# Epoch 2/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7218 - accuracy: 0.1686
# Epoch 00002: val_accuracy improved from 0.00781 to 0.09375, saving model to ./k_fold_models/model_4.h5
# 257/257 [==============================] - 30s 119ms/step - loss: 2.7218 - accuracy: 0.1686 - val_loss: 3.1170 - val_accuracy: 0.0938
# Epoch 3/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7183 - accuracy: 0.1754
# Epoch 00003: val_accuracy did not improve from 0.09375
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7183 - accuracy: 0.1754 - val_loss: 15.7090 - val_accuracy: 0.0039
# Epoch 4/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7083 - accuracy: 0.1628
# Epoch 00004: val_accuracy did not improve from 0.09375
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7083 - accuracy: 0.1628 - val_loss: 4.0135 - val_accuracy: 0.0664
# Epoch 5/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7151 - accuracy: 0.1745
# Epoch 00005: val_accuracy did not improve from 0.09375
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7151 - accuracy: 0.1745 - val_loss: 3.7376 - val_accuracy: 0.0234
# Epoch 6/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7026 - accuracy: 0.1540
# Epoch 00006: val_accuracy did not improve from 0.09375
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7026 - accuracy: 0.1540 - val_loss: 3.7493 - val_accuracy: 0.0352
# Epoch 7/10
# 257/257 [==============================] - ETA: 0s - loss: 2.6877 - accuracy: 0.1657
# Epoch 00007: val_accuracy did not improve from 0.09375
# 257/257 [==============================] - 30s 117ms/step - loss: 2.6877 - accuracy: 0.1657 - val_loss: 6.6252 - val_accuracy: 0.0078
# Epoch 8/10
# 257/257 [==============================] - ETA: 0s - loss: 2.6862 - accuracy: 0.1657
# Epoch 00008: val_accuracy did not improve from 0.09375
# 257/257 [==============================] - 30s 118ms/step - loss: 2.6862 - accuracy: 0.1657 - val_loss: 3.9978 - val_accuracy: 0.0625
# Epoch 9/10
# 257/257 [==============================] - ETA: 0s - loss: 2.6740 - accuracy: 0.1637
# Epoch 00009: val_accuracy did not improve from 0.09375
# 257/257 [==============================] - 30s 118ms/step - loss: 2.6740 - accuracy: 0.1637 - val_loss: 5.4912 - val_accuracy: 0.0234
# Epoch 10/10
# 257/257 [==============================] - ETA: 0s - loss: 2.6851 - accuracy: 0.1754
# Epoch 00010: val_accuracy did not improve from 0.09375
# 257/257 [==============================] - 30s 117ms/step - loss: 2.6851 - accuracy: 0.1754 - val_loss: 7.1420 - val_accuracy: 0.0117
# Epoch 1/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7216 - accuracy: 0.1667
# Epoch 00001: val_accuracy improved from -inf to 0.02734, saving model to ./k_fold_models/model_5.h5
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7216 - accuracy: 0.1667 - val_loss: 3.7270 - val_accuracy: 0.0273
# Epoch 2/10
# 257/257 [==============================] - ETA: 0s - loss: 2.6947 - accuracy: 0.1628
# Epoch 00002: val_accuracy did not improve from 0.02734
# 257/257 [==============================] - 30s 118ms/step - loss: 2.6947 - accuracy: 0.1628 - val_loss: 9.8305 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 257/257 [==============================] - ETA: 0s - loss: 2.7034 - accuracy: 0.1637
# Epoch 00003: val_accuracy improved from 0.02734 to 0.09375, saving model to ./k_fold_models/model_5.h5
# 257/257 [==============================] - 30s 118ms/step - loss: 2.7034 - accuracy: 0.1637 - val_loss: 6.2691 - val_accuracy: 0.0938
# Epoch 4/10
# 257/257 [==============================] - ETA: 0s - loss: 2.6930 - accuracy: 0.1764
# Epoch 00004: val_accuracy did not improve from 0.09375
# 257/257 [==============================] - 30s 118ms/step - loss: 2.6930 - accuracy: 0.1764 - val_loss: 16.5168 - val_accuracy: 0.0039
# Epoch 5/10
# 257/257 [==============================] - ETA: 0s - loss: 2.6892 - accuracy: 0.1657
# Epoch 00005: val_accuracy did not improve from 0.09375
# 257/257 [==============================] - 30s 118ms/step - loss: 2.6892 - accuracy: 0.1657 - val_loss: 12.9446 - val_accuracy: 0.0039
# Epoch 6/10
# 257/257 [==============================] - ETA: 0s - loss: 2.6750 - accuracy: 0.1667
# Epoch 00006: val_accuracy improved from 0.09375 to 0.13672, saving model to ./k_fold_models/model_5.h5
# 257/257 [==============================] - 30s 118ms/step - loss: 2.6750 - accuracy: 0.1667 - val_loss: 3.2247 - val_accuracy: 0.1367
# Epoch 7/10
# 257/257 [==============================] - ETA: 0s - loss: 2.6627 - accuracy: 0.1676
# Epoch 00007: val_accuracy did not improve from 0.13672
# 257/257 [==============================] - 30s 118ms/step - loss: 2.6627 - accuracy: 0.1676 - val_loss: 8.4166 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 257/257 [==============================] - ETA: 0s - loss: 2.6594 - accuracy: 0.1784
# Epoch 00008: val_accuracy did not improve from 0.13672
# 257/257 [==============================] - 30s 118ms/step - loss: 2.6594 - accuracy: 0.1784 - val_loss: 13.7142 - val_accuracy: 0.0156
# Epoch 9/10
# 257/257 [==============================] - ETA: 0s - loss: 2.6619 - accuracy: 0.1715
# Epoch 00009: val_accuracy did not improve from 0.13672
# 257/257 [==============================] - 30s 117ms/step - loss: 2.6619 - accuracy: 0.1715 - val_loss: 18.3061 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 257/257 [==============================] - ETA: 0s - loss: 2.6470 - accuracy: 0.1754
# Epoch 00010: val_accuracy did not improve from 0.13672
# 257/257 [==============================] - 30s 118ms/step - loss: 2.6470 - accuracy: 0.1754 - val_loss: 4.0587 - val_accuracy: 0.0352

# %%
idx = np.random.choice(len(x_train))
sample, sample_label = x_train[idx], y_train[idx]

test_model = build_model()
test_model.set_weights(k_fold_model.get_weights())
result = tf.argmax(test_model.predict_on_batch(tf.expand_dims(sample, 0)), axis=1)
print(f'Predicted result is: {code_to_label(result.numpy())}, target result is: {code_to_label([sample_label])}')

for model_file in os.listdir(os.path.join(os.getcwd(), 'k_fold_models')):
    test_model.load_weights(os.path.join(os.getcwd(), 'k_fold_models', model_file))
    result = tf.argmax(test_model.predict_on_batch(tf.expand_dims(sample, 0)), axis=1)
    print(f'{model_file} predicted result is: {code_to_label(result.numpy())}')
# Out:
# Predicted result is: Pyotr Ilyich Tchaikovsky, target result is: Johann Sebastian Bach
# model_1.h5 predicted result is: Frédéric Chopin
# model_2.h5 predicted result is: Franz Schubert
# model_3.h5 predicted result is: Franz Schubert
# model_4.h5 predicted result is: Johann Sebastian Bach
# model_5.h5 predicted result is: Johann Sebastian Bach
